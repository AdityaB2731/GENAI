# %%
# !pip install -q transformers accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.4 MB/s eta 0:00:00

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

model_id = "Qwen/Qwen2-1.8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_id,trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_id,trust_remote_code=True,torch_dtype=torch.float16,device_map="auto")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.67G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/206 [00:00<?, ?B/s]

# %%
input_text="Explain how transformers work in simple terms."
inputs = tokenizer(input_text,return_tensors="pt").to(model.device)
outputs = model.generate(**inputs,max_new_tokens=200)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# Explain how transformers work in simple terms. Transformers are a type of neural network architecture that is commonly used for processing sequential data, such as text or speech, where the input and output sequences have different lengths or the order of elements within each sequence can be reversed.
# The basic idea behind a transformer is to use multiple layers of self-attention mechanisms to capture the relationships between words or features in the input sequence. Self-attention is a mechanism that allows a query word (which might be a shorter subsequence of the input sequence) to focus on specific parts of the sequence while ignoring others. This helps the model to identify which words are most relevant to predicting the next element in the sequence, even if those words are not part of the original input sequence.
#
# ...

# %%
input_text="Explain how transformers work in simple terms."
inputs = tokenizer(input_text, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs)  # max_tokens is removed
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Explain how transformers work in simple terms. Transformers are neural networks that are designed to take input data and transform it into a different representation, called
